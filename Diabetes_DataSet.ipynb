# %% [markdown]
# <a href="https://colab.research.google.com/github/hazelortegaaa/Summer/blob/main/Diabetes_DataSet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Task 1: Identify the problem

# %% [markdown]
# The dataset represents 10 years (1999-2008) of clinical care at 130 US hospitals and integrated delivery networks. It includes over 50 features representing patient and hospital outcomes. Information was extracted from the database for encounters that satisfied the following criteria.
#
# *   (1) It is an inpatient encounter (a hospital admission).
# *   (2) It is a diabetic encounter, that is, one during which any kind of diabetes was entered to the system as a diagnosis.
#
# *   (3) The length of stay was at least 1 day and at most 14 days.
# *   (4) Laboratory tests were performed during the encounter.
#
# *   (5) Medications were administered during the encounter.
# The data contains such attributes as patient number, race, gender, age, admission type, time in hospital, medical specialty of admitting physician, number of lab test performed, HbA1c test result, diagnosis, number of medication, diabetic medications, number of outpatient, inpatient, and emergency visits in the year before the hospitalization, etc.

# %% [markdown]
# ##Task 2: Load the libraries

# %%
import pandas as pd #Import pandas as np
import numpy as np #Import numpy as np
import matplotlib.pyplot as plt #Import plt
import seaborn as sns #Import seaborn as sns
sns.set()

# %% [markdown]
# ##Task 3: Load the data

# %%
diabetes = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/diabetic_data.csv')

# %% [markdown]
# ##Task 4: EDA (Exploratory Data Analysis)

# %%
diabetes.head() #We see the first five columns
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# ...

# %%
diabetes.columns #All the information form the data such as race, age, gender, etc
# Out:
# Index(['encounter_id', 'patient_nbr', 'race', 'gender', 'age', 'weight',
#        'admission_type_id', 'discharge_disposition_id', 'admission_source_id',
#        'time_in_hospital', 'payer_code', 'medical_specialty',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1',
#        'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum', 'A1Cresult',
#        'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide',
#        'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'examide', 'citoglipton', 'insulin',
#        'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#        'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted'],
#       dtype='object')

# %%
diabetes.isnull()
# Out:
#         encounter_id  patient_nbr   race  gender    age  weight  \
# 0              False        False  False   False  False   False
# 1              False        False  False   False  False   False
# 2              False        False  False   False  False   False
# 3              False        False  False   False  False   False
# 4              False        False  False   False  False   False
# ...              ...          ...    ...     ...    ...     ...
# 101761         False        False  False   False  False   False
# 101762         False        False  False   False  False   False
# 101763         False        False  False   False  False   False
# 101764         False        False  False   False  False   False
# 101765         False        False  False   False  False   False
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                   False                     False                False
# ...

# %%
diabetes.describe()
# Out:
#        encounter_id   patient_nbr  admission_type_id  \
# count  1.017660e+05  1.017660e+05      101766.000000
# mean   1.652016e+08  5.433040e+07           2.024006
# std    1.026403e+08  3.869636e+07           1.445403
# min    1.252200e+04  1.350000e+02           1.000000
# 25%    8.496119e+07  2.341322e+07           1.000000
# 50%    1.523890e+08  4.550514e+07           1.000000
# 75%    2.302709e+08  8.754595e+07           3.000000
# max    4.438672e+08  1.895026e+08           8.000000
#
#        discharge_disposition_id  admission_source_id  time_in_hospital  \
# count             101766.000000        101766.000000     101766.000000
# mean                   3.715642             5.754437          4.395987
# std                    5.280166             4.064081          2.985108
# min                    1.000000             1.000000          1.000000
# 25%                    1.000000             1.000000          2.000000
# ...

# %%
diabetes
# Out:
#         encounter_id  patient_nbr             race  gender      age weight  \
# 0            2278392      8222157        Caucasian  Female   [0-10)      ?
# 1             149190     55629189        Caucasian  Female  [10-20)      ?
# 2              64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3             500364     82442376        Caucasian    Male  [30-40)      ?
# 4              16680     42519267        Caucasian    Male  [40-50)      ?
# ...              ...          ...              ...     ...      ...    ...
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)      ?
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)      ?
# 101763     443854148     41088789        Caucasian    Male  [70-80)      ?
# 101764     443857166     31693671        Caucasian  Female  [80-90)      ?
# 101765     443867222    175429310        Caucasian    Male  [70-80)      ?
#
# ...

# %%
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101766 entries, 0 to 101765
# Data columns (total 50 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   encounter_id              101766 non-null  int64
#  1   patient_nbr               101766 non-null  int64
#  2   race                      101766 non-null  object
#  3   gender                    101766 non-null  object
#  4   age                       101766 non-null  object
#  5   weight                    101766 non-null  object
#  6   admission_type_id         101766 non-null  int64
#  7   discharge_disposition_id  101766 non-null  int64
#  8   admission_source_id       101766 non-null  int64
#  9   time_in_hospital          101766 non-null  int64
#  10  payer_code                101766 non-null  object
#  11  medical_specialty         101766 non-null  object
#  12  num_lab_procedures        101766 non-null  int64
# ...

# %%
diabetes.isnull().sum()
# Out:
# encounter_id                0
# patient_nbr                 0
# race                        0
# gender                      0
# age                         0
# admission_type_id           0
# discharge_disposition_id    0
# admission_source_id         0
# time_in_hospital            0
# payer_code                  0
# medical_specialty           0
# num_lab_procedures          0
# num_procedures              0
# num_medications             0
# number_outpatient           0
# number_emergency            0
# number_inpatient            0
# diag_1                      0
# diag_2                      0
# diag_3                      0
# number_diagnoses            0
# max_glu_serum               0
# A1Cresult                   0
# metformin                   0
# repaglinide                 0
# nateglinide                 0
# chlorpropamide              0
# glimepiride                 0
# acetohexamide               0
# glipizide                   0
# glyburide                   0
# ...

# %%
#We're going to drop the column 'weight'
diabetes = diabetes.drop(['weight', 'payer_code', 'medical_specialty'], axis = 1)

# %%
#Notice that 'weight' and 'payer_code' and 'medical_specialty' is now dropped
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101766 entries, 0 to 101765
# Data columns (total 47 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   encounter_id              101766 non-null  int64
#  1   patient_nbr               101766 non-null  int64
#  2   race                      101766 non-null  object
#  3   gender                    101766 non-null  object
#  4   age                       101766 non-null  object
#  5   admission_type_id         101766 non-null  int64
#  6   discharge_disposition_id  101766 non-null  int64
#  7   admission_source_id       101766 non-null  int64
#  8   time_in_hospital          101766 non-null  int64
#  9   num_lab_procedures        101766 non-null  int64
#  10  num_procedures            101766 non-null  int64
#  11  num_medications           101766 non-null  int64
#  12  number_outpatient         101766 non-null  int64
# ...

# %%
diabetes.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age  \
# 0       2278392      8222157        Caucasian  Female   [0-10)
# 1        149190     55629189        Caucasian  Female  [10-20)
# 2         64410     86047875  AfricanAmerican  Female  [20-30)
# 3        500364     82442376        Caucasian    Male  [30-40)
# 4         16680     42519267        Caucasian    Male  [40-50)
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  num_lab_procedures  ...  citoglipton  insulin  \
# 0                 1                  41  ...           No       No
# ...

# %%
diabetes.isnull().value_counts()
# Out:
# encounter_id  patient_nbr  race   gender  age    weight  admission_type_id  discharge_disposition_id  admission_source_id  time_in_hospital  payer_code  medical_specialty  num_lab_procedures  num_procedures  num_medications  number_outpatient  number_emergency  number_inpatient  diag_1  diag_2  diag_3  number_diagnoses  max_glu_serum  A1Cresult  metformin  repaglinide  nateglinide  chlorpropamide  glimepiride  acetohexamide  glipizide  glyburide  tolbutamide  pioglitazone  rosiglitazone  acarbose  miglitol  troglitazone  tolazamide  examide  citoglipton  insulin  glyburide-metformin  glipizide-metformin  glimepiride-pioglitazone  metformin-rosiglitazone  metformin-pioglitazone  change  diabetesMed  readmitted
# ...

# %%
#Notice we have 50 columns
diabetes.shape
# Out:
# (101766, 49)

# %%
print(diabetes.keys())
# Out:
# Index(['encounter_id', 'patient_nbr', 'race', 'gender', 'age', 'weight',
#        'admission_type_id', 'discharge_disposition_id', 'admission_source_id',
#        'time_in_hospital', 'payer_code', 'medical_specialty',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1',
#        'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum', 'A1Cresult',
#        'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide',
#        'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'examide', 'citoglipton', 'insulin',
#        'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#        'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted'],
#       dtype='object')

# %% [markdown]
# ##Task 5: Data Visualizations

# %%
sns.countplot(x = "gender", data = diabetes)  #We can see that most patients are female than male from the dataset
plt.show()

# %%
#We can see that the race is mostly Causcasian, African American. The lowest is other, Asian and Hispanic
plt.figure(figsize=(12,8))
sns.countplot(x = "race", data = diabetes) 
plt.show()

# %%
 #We can see that most patients are in ages from 60-70 and 70-80 
plt.figure(figsize=(20,15))
sns.countplot(x = "age", data = diabetes)  
plt.show()

# %%
plt.figure(figsize=(20,15)) #I decided to use countplot again and see how would the graph look like for weight. Since it's a '?', it really doesn't tell us anything
sns.countplot(x = "weight", data = diabetes)  
plt.show()

# %%
sns.countplot(x = "time_in_hospital", data = diabetes) #We can see that in this graph the time in hospital by some patients, it goes from high to low
plt.show()

# %%
#In this graph we can able to see the number of medications, I decided to make the graph look bigger to it would be more organized and the number 
#of medications is visible

plt.figure(figsize=(20,15))
sns.countplot(x = "num_medications", data = diabetes)  
plt.show()

# %% [markdown]
# ##Changing objects into integer pt1

# %%
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101766 entries, 0 to 101765
# Data columns (total 49 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   encounter_id              101766 non-null  int64
#  1   patient_nbr               101766 non-null  int64
#  2   race                      101766 non-null  object
#  3   gender                    101766 non-null  object
#  4   age                       101766 non-null  object
#  5   admission_type_id         101766 non-null  int64
#  6   discharge_disposition_id  101766 non-null  int64
#  7   admission_source_id       101766 non-null  int64
#  8   time_in_hospital          101766 non-null  int64
#  9   payer_code                101766 non-null  object
#  10  medical_specialty         101766 non-null  object
#  11  num_lab_procedures        101766 non-null  int64
#  12  num_procedures            101766 non-null  int64
# ...

# %%
#For this part I had to look it up because I wasn't really sure how to proceededw with this part of the data 
#Credits: https://github.com/zachzazueta/Diabetes_Readmittance_Predictions/blob/master/Zazueta%20-%20Mod%205%20Project.ipynb 

#Drop the rows where Race is not specified
data = diabetes[diabetes['race'] != '?']

#Drop the rows where Gender is not specified
data = data[data['gender'] != 'Unknown/Invalid']

#Drop the columns with a significant number of missing values
data = data.drop(['weight', 'payer_code', 'medical_specialty'], axis=1)

# %%
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101766 entries, 0 to 101765
# Data columns (total 50 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   encounter_id              101766 non-null  int64
#  1   patient_nbr               101766 non-null  int64
#  2   race                      101766 non-null  object
#  3   gender                    101766 non-null  object
#  4   age                       101766 non-null  object
#  5   weight                    101766 non-null  object
#  6   admission_type_id         101766 non-null  int64
#  7   discharge_disposition_id  101766 non-null  int64
#  8   admission_source_id       101766 non-null  int64
#  9   time_in_hospital          101766 non-null  int64
#  10  payer_code                101766 non-null  object
#  11  medical_specialty         101766 non-null  object
#  12  num_lab_procedures        101766 non-null  int64
# ...

# %%
diabetes.readmitted.value_counts() #Data that we have to check if any patients have been readmitted
# Out:
# NO     54864
# >30    35545
# <30    11357
# Name: readmitted, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler

lbe = LabelEncoder()
diabetes['readmitted'] = lbe.fit_transform(diabetes['readmitted'])
diabetes['readmitted'] = diabetes['readmitted'].apply(lambda x: 'No_readmit' if x >1 
                                              else 'Readmit')
diabetes['readmitted'] = diabetes['readmitted'].astype('category')
diabetes.readmitted.value_counts()
# Out:
# No_readmit    54864
# Readmit       46902
# Name: readmitted, dtype: int64

# %%
diabetes = diabetes.drop(['admission_source_id', 'diag_1', 'diag_2', 'diag_3', 
                  'max_glu_serum', 'metformin', 'repaglinide', 'nateglinide', 
                  'chlorpropamide', 'glimepiride', 'acetohexamide', 'glipizide', 
                  'glyburide', 'tolbutamide', 'pioglitazone', 'rosiglitazone', 
                  'acarbose', 'miglitol', 'troglitazone', 'tolazamide', 
                  'examide', 'citoglipton', 'glyburide-metformin', 
                  'glipizide-metformin', 'glimepiride-pioglitazone', 
                  'metformin-rosiglitazone', 'metformin-pioglitazone', 
                  'diabetesMed'], axis=1)
#We are dropping columns we dont't need

# %%
diabetes.columns
# Out:
# Index(['encounter_id', 'patient_nbr', 'race', 'gender', 'age', 'weight',
#        'admission_type_id', 'discharge_disposition_id', 'admission_source_id',
#        'time_in_hospital', 'payer_code', 'medical_specialty',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1',
#        'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum', 'A1Cresult',
#        'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide',
#        'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'examide', 'citoglipton', 'insulin',
#        'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#        'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted'],
#       dtype='object')

# %%
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101766 entries, 0 to 101765
# Data columns (total 50 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   encounter_id              101766 non-null  int64
#  1   patient_nbr               101766 non-null  int64
#  2   race                      101766 non-null  object
#  3   gender                    101766 non-null  object
#  4   age                       101766 non-null  object
#  5   weight                    101766 non-null  object
#  6   admission_type_id         101766 non-null  int64
#  7   discharge_disposition_id  101766 non-null  int64
#  8   admission_source_id       101766 non-null  int64
#  9   time_in_hospital          101766 non-null  int64
#  10  payer_code                101766 non-null  object
#  11  medical_specialty         101766 non-null  object
#  12  num_lab_procedures        101766 non-null  int64
# ...

# %% [markdown]
# ##Here, we have  to change object into integer / Cleaning part

# %%
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101766 entries, 0 to 101765
# Data columns (total 50 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   encounter_id              101766 non-null  int64
#  1   patient_nbr               101766 non-null  int64
#  2   race                      101766 non-null  object
#  3   gender                    101766 non-null  object
#  4   age                       101766 non-null  object
#  5   weight                    101766 non-null  object
#  6   admission_type_id         101766 non-null  int64
#  7   discharge_disposition_id  101766 non-null  int64
#  8   admission_source_id       101766 non-null  int64
#  9   time_in_hospital          101766 non-null  int64
#  10  payer_code                101766 non-null  object
#  11  medical_specialty         101766 non-null  object
#  12  num_lab_procedures        101766 non-null  int64
# ...

# %%
diabetes['gender'] = diabetes['gender'].replace(['Male'], 1)
diabetes['gender'] = diabetes['gender'].replace(['Female'], 0)

# %%
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101766 entries, 0 to 101765
# Data columns (total 50 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   encounter_id              101766 non-null  int64
#  1   patient_nbr               101766 non-null  int64
#  2   race                      101766 non-null  object
#  3   gender                    101766 non-null  object
#  4   age                       101766 non-null  object
#  5   weight                    101766 non-null  object
#  6   admission_type_id         101766 non-null  int64
#  7   discharge_disposition_id  101766 non-null  int64
#  8   admission_source_id       101766 non-null  int64
#  9   time_in_hospital          101766 non-null  int64
#  10  payer_code                101766 non-null  object
#  11  medical_specialty         101766 non-null  object
#  12  num_lab_procedures        101766 non-null  int64
# ...

# %%
diabetes.isna().sum() #This will return the sum of missing values in each one of the columns
# Out:
# encounter_id                0
# patient_nbr                 0
# race                        0
# gender                      0
# age                         0
# weight                      0
# admission_type_id           0
# discharge_disposition_id    0
# time_in_hospital            0
# payer_code                  0
# medical_specialty           0
# num_lab_procedures          0
# num_procedures              0
# num_medications             0
# number_outpatient           0
# number_emergency            0
# number_inpatient            0
# number_diagnoses            0
# A1Cresult                   0
# insulin                     0
# change                      0
# readmitted                  0
# dtype: int64

# %% [markdown]
# ##Task 6: Train, test, split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(diabetes.drop(['readmitted'],axis=1), diabetes['readmitted'], test_size= 0.3, random_state =1)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel = LogisticRegression()

# %% [markdown]
# ##Task 7: KNN

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(diabetes.drop('readmitted', axis=1))

# %%
scaled_features = scaler.transform(diabetes.drop('readmitted', axis=1))
StandardScaler(copy = True, with_mean = True, with_std = True)

# %%
X_train, X_test, y_train, y_test = train_test_split(scaled_features, diabetes['readmitted'], test_size = 0.33)

# %% [markdown]
# ##Task 8:

# %%
X_train, X_test, y_train, y_test = train_test_split(scaled_features, diabetes['readmitted'], test_size = 0.33)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(X_train,y_train)

# %%
pred = knn.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
pred = diabetes.predict(X_test)

# %%
knn.fit(X_train, y_train)
pred = knn.predict(X_test)

# %%
print(classification_report(y_test,pred))

# %%
#Had some trouble with a string that I wasn't sure where it was coming from.

# %% [markdown]
# ##Task 9:

# %% [markdown]
# ##Task 10: Predictions
