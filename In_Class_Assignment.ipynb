# %% [markdown]
# <a href="https://colab.research.google.com/github/hazelortegaaa/Summer/blob/main/In_Class_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Task 1: Identify the problem

# %% [markdown]
# In this section we are conducting an analysis in which we are given the dataset of sepal lenght, speal width, petal lenght, petal with and class.

# %% [markdown]
# ##Task 2: Load the libraries

# %%
import pandas as pd #Import pandas as np
import numpy as np #Import numpy as np
import matplotlib.pyplot as plt #Import plt
import seaborn as sns #Import seaborn as sns
sns.set()

# %% [markdown]
# ##Task 3: Load the data

# %%
fl = pd.read_csv('https://raw.githubusercontent.com/hazelortegaaa/data/main/iris.csv') #Import the raw data ad pd.read_csv

# %% [markdown]
# ##Task 4: EDA (Exploratory Data Analysis)

# %%
fl.head() #Shows the first five columns of data
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width   Class
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
fl.describe() #Will show 'Sepal_lenght', 'Sepal_Witdh', 'Petal_Lenght', and 'Petal_withd'from the data we are using
# Out:
#        Sepal_Length  Sepal_Width  Petal_Length  Petal_Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
fl.isnull()
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width  Class
# 0           False        False         False        False  False
# 1           False        False         False        False  False
# 2           False        False         False        False  False
# 3           False        False         False        False  False
# 4           False        False         False        False  False
# ..            ...          ...           ...          ...    ...
# 145         False        False         False        False  False
# 146         False        False         False        False  False
# 147         False        False         False        False  False
# 148         False        False         False        False  False
# 149         False        False         False        False  False
#
# [150 rows x 5 columns]

# %%
fl.info() #Shows information of fl
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal_Length  150 non-null    float64
#  1   Sepal_Width   150 non-null    float64
#  2   Petal_Length  150 non-null    float64
#  3   Petal_Width   150 non-null    float64
#  4   Class         150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
fl.isnull().value_counts()
# Out:
# Sepal_Length  Sepal_Width  Petal_Length  Petal_Width  Class
# False         False        False         False        False    150
# dtype: int64

# %%
fl.describe()
# Out:
#        Sepal_Length  Sepal_Width  Petal_Length  Petal_Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
fl.columns
# Out:
# Index(['Sepal_Length', 'Sepal_Width', 'Petal_Length', 'Petal_Width', 'Class'], dtype='object')

# %%
fl['Class'] = fl['Class'].replace(['Setosa'],'1')
fl['Class'] = fl['Class'].replace(['Versicolor'],'2')
fl['Class'] = fl['Class'].replace(['Virginica'],'3')

# %% [markdown]
# ##Task 5: Data Visualization

# %%
sns.countplot(data = fl, x = 'Class') #Different types of graphs using sns

# %%
sns.pairplot(fl,hue='Sepal_Width',palette='coolwarm') #Different types of graphs using sns

# %%
sns.pairplot(fl,hue='Petal_Width',palette='gist_rainbow') #Different types of graphs using sns

# %%
sns.pairplot(fl, kind="hist") #Different types of graphs using sns

# %%
sns.pairplot(fl, hue='Class') #Different types of graphs using sns

# %% [markdown]
# ##Task 6: Train, test, split

# %%
from sklearn.model_selection import train_test_split #Test train test split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.10)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler =StandardScaler()

# %%
scaler.fit(fl.drop('Class',axis=1))
# Out:
# StandardScaler()

# %%
scaled_features = scaler.transform(fl.drop('Class', axis = 1))

# %%
scaled_features
# Out:
# array([[-9.00681170e-01,  1.01900435e+00, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.14301691e+00, -1.31979479e-01, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.38535265e+00,  3.28414053e-01, -1.39706395e+00,
#         -1.31544430e+00],
#        [-1.50652052e+00,  9.82172869e-02, -1.28338910e+00,
#         -1.31544430e+00],
#        [-1.02184904e+00,  1.24920112e+00, -1.34022653e+00,
#         -1.31544430e+00],
#        [-5.37177559e-01,  1.93979142e+00, -1.16971425e+00,
#         -1.05217993e+00],
#        [-1.50652052e+00,  7.88807586e-01, -1.34022653e+00,
#         -1.18381211e+00],
#        [-1.02184904e+00,  7.88807586e-01, -1.28338910e+00,
#         -1.31544430e+00],
#        [-1.74885626e+00, -3.62176246e-01, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.14301691e+00,  9.82172869e-02, -1.28338910e+00,
#         -1.44707648e+00],
#        [-5.37177559e-01,  1.47939788e+00, -1.28338910e+00,
#         -1.31544430e+00],
# ...

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
error_rate = []
# Will take some time
for i in range(1,40):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,y_train)
    pred_i = knn.predict(X_test)
    error_rate.append(np.mean(pred_i != y_test))

# %%
plt.figure(figsize=(12,8))
plt.plot(range(1,40), error_rate, color='red', linestyle='dashed', marker='o', markerfacecolor='red', markersize=10)
plt.title('Error Rate vs K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
pred = knn.predict(X_test)

# %%
print('K is = 1')
print(confusion_matrix(y_test,pred))
# Out:
# K is = 1
# [[0 2 4]
#  [2 3 2]
#  [1 0 1]]

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         6
#            1       0.60      0.43      0.50         7
#            2       0.14      0.50      0.22         2
#
#     accuracy                           0.27        15
#    macro avg       0.25      0.31      0.24        15
# weighted avg       0.30      0.27      0.26        15

# %%
#Second data split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler =StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
error_rate = []
# Will take some time
for i in range(1,40):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,y_train)
    pred_i = knn.predict(X_test)
    error_rate.append(np.mean(pred_i != y_test))

# %%
plt.figure(figsize=(12,8))
plt.plot(range(1,40), error_rate, color='red', linestyle='dashed', marker='o', markerfacecolor='red', markersize=10)
plt.title('Error Rate vs K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
pred = knn.predict(X_test)

# %%
print('K is = 2')
print(confusion_matrix(y_test,pred))
# Out:
# K is = 2
# [[12  0  0]
#  [ 0  8  1]
#  [ 0  2  7]]

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        12
#            1       0.80      0.89      0.84         9
#            2       0.88      0.78      0.82         9
#
#     accuracy                           0.90        30
#    macro avg       0.89      0.89      0.89        30
# weighted avg       0.90      0.90      0.90        30

# %%
#Third data split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler =StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
error_rate = []
# Will take some time
for i in range(1,40):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,y_train)
    pred_i = knn.predict(X_test)
    error_rate.append(np.mean(pred_i != y_test))

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
pred = knn.predict(X_test)

# %%
print('K is = 3')
print(confusion_matrix(y_test,pred))
# Out:
# K is = 3
# [[12  0  0]
#  [ 0 19  2]
#  [ 0  0 12]]

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        12
#            1       1.00      0.90      0.95        21
#            2       0.86      1.00      0.92        12
#
#     accuracy                           0.96        45
#    macro avg       0.95      0.97      0.96        45
# weighted avg       0.96      0.96      0.96        45

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
pred = knn.predict(X_test)

# %%
fl['Class'] = fl['Class'].replace(['Setosa'],'1')
fl['Class'] = fl['Class'].replace(['Versicolor'],'2')
fl['Class'] = fl['Class'].replace(['Virginica'],'2  ')

# %% [markdown]
# ##Task 7: Logistic Regression

# %%
from sklearn.model_selection import train_test_split

# %%
x = fl.iloc[:,[0,4]].values
y = fl.iloc[:, -1].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 1) #Will show the data spli by using train_test_split

# %%
from sklearn.linear_model import LogisticRegression

# %%
classifier = LogisticRegression(random_state=0)
classifier.fit(X_train,y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
classifier.score(X_test,y_test)
# Out:
# 0.9666666666666667

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(confusion_matrix(y_test,pred))
# Out:
# [[11  0  0]
#  [ 0 12  1]
#  [ 0  0  6]]

# %%
knn.fit(X_train, y_train)
pred = knn.predict(X_test)

# %% [markdown]
# ##Task 8: Conduct KNN

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       0.94      0.94      0.94        18
#            2       0.91      0.91      0.91        11
#
#     accuracy                           0.96        45
#    macro avg       0.95      0.95      0.95        45
# weighted avg       0.96      0.96      0.96        45

# %% [markdown]
# ##Task 8: Conduct KNN (part 2)

# %%
knn = KNeighborsClassifier(n_neighbors=3)

# %%
knn.fit(X_train, y_train)
pred = knn.predict(X_test)

# %%
print('K is = 5')
print(confusion_matrix(y_test,pred))
# Out:
# With k = 5
# [[16  0  0]
#  [ 0 17  1]
#  [ 0  0 11]]

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       1.00      0.94      0.97        18
#            2       0.92      1.00      0.96        11
#
#     accuracy                           0.98        45
#    macro avg       0.97      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45

# %%
knn = KNeighborsClassifier(n_neighbors=20)
knn.fit(X_train, y_train)
pred = knn.predict(X_test)
print('With k = 40')
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# With k = 40
# [[16  0  0]
#  [ 0 17  1]
#  [ 0  0 11]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       1.00      0.94      0.97        18
#            2       0.92      1.00      0.96        11
#
#     accuracy                           0.98        45
#    macro avg       0.97      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45

# %% [markdown]
# ##Task 9:Conduct the Logistic Regression on the Data

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel = LogisticRegression()

# %%
logmodel.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
predictions = logmodel.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       1.00      0.94      0.97        18
#            2       0.92      1.00      0.96        11
#
#     accuracy                           0.98        45
#    macro avg       0.97      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45

# %%
error_rate = []
# Will take some time
for i in range(1,40):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,y_train)
    pred_i = knn.predict(X_test)
    error_rate.append(np.mean(pred_i != y_test))

# %%
error_rate
# Out:
# [0.044444444444444446,
#  0.044444444444444446,
#  0.022222222222222223,
#  0.044444444444444446,
#  0.022222222222222223,
#  0.022222222222222223,
#  0.022222222222222223,
#  0.022222222222222223,
#  0.022222222222222223,
#  0.022222222222222223,
#  0.022222222222222223,
#  0.022222222222222223,
#  0.022222222222222223,
#  0.022222222222222223,
#  0.022222222222222223,
#  0.022222222222222223,
#  0.022222222222222223,
#  0.022222222222222223,
#  0.022222222222222223,
#  0.022222222222222223,
#  0.022222222222222223,
#  0.022222222222222223,
#  0.022222222222222223,
#  0.022222222222222223,
#  0.022222222222222223,
#  0.044444444444444446,
#  0.044444444444444446,
#  0.044444444444444446,
#  0.022222222222222223,
#  0.022222222222222223,
#  0.022222222222222223,
#  0.022222222222222223,
#  0.022222222222222223,
#  0.044444444444444446,
#  0.022222222222222223,
#  0.022222222222222223,
#  0.022222222222222223,
#  0.022222222222222223,
#  0.022222222222222223]
